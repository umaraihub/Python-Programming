# %% [markdown]
# ## List in Python

# %%
#Define List
fruits = ["Apple", "Orange","Banana"]
print(fruits)
# Out:
# ['Apple', 'Orange', 'Banana']

# %%
print(fruits[0]) #access first element of the list
# Out:
# Apple

# %% [markdown]
# ## Functions(Methods) of List

# %% [markdown]
# ## 1. append()

# %%
fruits.append("Kiwi") #add element at the end of the list
print(fruits)
# Out:
# ['Apple', 'Orange', 'Banana', 'Kiwi']

# %% [markdown]
# ## 2. insert()

# %%
fruits.insert(1,"Cherry") #add element at first index of the list
print(fruits)
# Out:
# ['Apple', 'Cherry', 'Orange', 'Banana', 'Kiwi']

# %% [markdown]
# ## 3. remove()

# %%
fruits.remove("Banana") #remove banana from the list using remove method
print(fruits)
# Out:
# ['Apple', 'Cherry', 'Orange', 'Kiwi']

# %% [markdown]
# ## 4. extend()

# %%
fruits.extend(["Watermelon","Pomegranate","Strawberry"]) #add mulitple elements at the end of the list
print(fruits)
# Out:
# ['Apple', 'Cherry', 'Orange', 'Kiwi', 'Watermelon', 'Pomegranate', 'Strawberry']

# %% [markdown]
# ## 5. pop()

# %%
fruits.pop() #remove last element from the list
# Out:
# 'Strawberry'

# %%
print(fruits)
# Out:
# ['Apple', 'Cherry', 'Orange', 'Kiwi', 'Watermelon', 'Pomegranate']

# %%
fruits.pop(1) #remove element from index 1
# Out:
# 'Cherry'

# %%
print(fruits)
# Out:
# ['Apple', 'Orange', 'Kiwi', 'Watermelon', 'Pomegranate']

# %% [markdown]
# ## 6. reverse()

# %%
#Elemnts in reverse order
fruits.reverse()

# %%
print(fruits)
# Out:
# ['Pomegranate', 'Watermelon', 'Kiwi', 'Orange', 'Apple']

# %% [markdown]
# ## 7. sort()

# %%
#Sort/Arrange Element
fruits.sort() #arrange element in ascending order

# %%
print(fruits)
# Out:
# ['Apple', 'Kiwi', 'Orange', 'Pomegranate', 'Watermelon']

# %%
fruits.sort(reverse = True) #arrange elements in descending order

# %%
print(fruits)
# Out:
# ['Watermelon', 'Pomegranate', 'Orange', 'Kiwi', 'Apple']

# %% [markdown]
# ## 8. len()

# %%
#Count the Number of Elements in the list
length = len(fruits)
print(length)
# Out:
# 5

# %% [markdown]
# ## 9. index()

# %%
#Find position of value
print(fruits.index("Apple")) #apple is at index 5 in the above updated list
# Out:
# 4

# %% [markdown]
# ## 10. count()

# %%
#Counts how many times a value appears in the list.
print(fruits.count("Apple"))
# Out:
# 1

# %% [markdown]
# ## 11. copy()

# %%
#Makes a duplicate list
new_fruits = fruits.copy()
print(new_fruits)
# Out:
# ['Watermelon', 'Pomegranate', 'Orange', 'Kiwi', 'Apple']

# %% [markdown]
# ## 12. clear()

# %%
#Removes all elements from the list(duplicate list) and make empty list
new_fruits.clear()
print(new_fruits)
# Out:
# []

# %% [markdown]
# ## Slicing (getting a part (portion) of a list

# %%
#print the original list of fruits
print(fruits)
# Out:
# ['Watermelon', 'Pomegranate', 'Orange', 'Kiwi', 'Apple']

# %%
#Slicing
fruits = fruits[1:4] #slice (start from index 2(orange) to index 4(Watermelon) ) but last index is not included
print(fruits)
# Out:
# ['Pomegranate', 'Orange', 'Kiwi']

# %%
#Now the fruits list is
print(fruits)
# Out:
# ['Pomegranate', 'Orange', 'Kiwi']

# %%
fruits[1] = "Grape"  #replace element at index 1(orange) with Grape

# %%
print(fruits)
# Out:
# ['Pomegranate', 'Grape', 'Kiwi']

# %%
#delete element from the fruits list using index number
del fruits[0]
print(fruits)
# Out:
# ['Grape', 'Kiwi']

# %%
#delete permanently list instead of making empty list 
del new_fruits

# %%
print(new_fruits) #Delete Entire List
#Error will occurBecause the whole list variable is deleted from memory.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[365], line 1
# ----> 1 print(new_fruits) #Delete Entire List
#       2 #Error will occurBecause the whole list variable is deleted from memory.
#
# NameError: name 'new_fruits' is not defined
